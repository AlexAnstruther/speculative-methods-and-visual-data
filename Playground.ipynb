# %% [markdown]
# # ML as a Method of Exploration: Modern Film Consumption & Letterboxd

# %% [markdown]
# ### Importing datasets and code libraries

# %%
# %run -i scripts/imports.py
# Out:
# All libraries successfully imported.

# %%
# %run -i scripts/data.py
# Out:
# All data successfully imported. Your datframes are: 'ratings_df' and 'movies_df'

# %% [markdown]
# ### Exploring the predictability of different film's ratings

# %%
# %run -i scripts/predictability.py
# Out:
# The least predictably rated film is: cinderella-2015 with an error of: 1.4445
# The most predictably rated film is: casablanca with an error of: 0.4065

# %% [markdown]
# ### Investigating a hunch relating predictability and release-date

# %%
# %run -i scripts/release-dates-by-predictability.py

# %% [markdown]
# ### Investigating a hunch relating predictability and genre count

# %%
# %run -i scripts/number-of-genres-by-predictability.py
